# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('C:\\Users\\chen jia ni\\Desktop\\wangyipy\\shujuji\\air1908.csv')

# %%
data.tail()#查看数据数
# Out:
#             Date   Time                                           Location  \
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 5263                           Jakarta - Maduin
# 5264                               Goma - Isiro
# 5265                     Rio de Janeiro - Paris
# ...

# %%
data.columns#查看数据有多少列，无（）
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary'],
#       dtype='object')

# %%
data.Type.value_counts()#统计机型
# Out:
# Douglas DC-3                                334
# de Havilland Canada DHC-6 Twin Otter 300     81
# Douglas C-47A                                74
# Douglas C-47                                 62
# Douglas DC-4                                 40
# Yakovlev YAK-40                              37
# Antonov AN-26                                36
# Junkers JU-52/3m                             32
# Douglas C-47B                                29
# De Havilland DH-4                            28
# Douglas DC-6B                                27
# Breguet 14                                   23
# Curtiss C-46A                                21
# Douglas C-47-DL                              20
# Douglas DC-6                                 20
# McDonnell Douglas DC-9-32                    19
# Antonov AN-24                                19
# Antonov AN-12                                19
# Embraer 110P1 Bandeirante                    18
# Curtiss C-46                                 18
# ...

# %%
data.Type.value_counts()[:10]#切片前10个
# Out:
# Douglas DC-3                                334
# de Havilland Canada DHC-6 Twin Otter 300     81
# Douglas C-47A                                74
# Douglas C-47                                 62
# Douglas DC-4                                 40
# Yakovlev YAK-40                              37
# Antonov AN-26                                36
# Junkers JU-52/3m                             32
# Douglas C-47B                                29
# De Havilland DH-4                            28
# Name: Type, dtype: int64

# %%
data.Type.value_counts()[:3]
# Out:
# Douglas DC-3                                334
# de Havilland Canada DHC-6 Twin Otter 300     81
# Douglas C-47A                                74
# Name: Type, dtype: int64

# %%
data['Year']=data.Date.map(lambda x: x.split('/')[-1])#截取时间的年份，用map应用于元素
data.Year.value_counts()[:5]#取前5位空难次数
# Out:
# 1972    104
# 1968     96
# 1989     95
# 1967     91
# 1979     89
# Name: Year, dtype: int64

# %%
data.groupby('Year')[['Fatalities']].sum().sort_values(by='Fatalities',ascending=False)[:5]#聚合分组，统计各年的死亡人数
# Out:
#       Fatalities
# Year
# 1972      2937.0
# 1985      2670.0
# 1973      2485.0
# 1996      2386.0
# 1974      2318.0

# %%
data['taoshenglv'] = (data.Aboard - data.Fatalities)/data.Aboard

# %%
data['survive']=(data.Aboard-data.Fatalities)/data.Aboard#进行计算，并赋值列

# %%
data.head(10)
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
# 5  03/05/1915  01:00                     Tienen, Belgium
# 6  09/03/1915  15:20               Off Cuxhaven, Germany
# 7  07/28/1916    NaN               Near Jambol, Bulgeria
# 8  09/24/1916  01:00                 Billericay, England
# 9  10/01/1916  23:45                Potters Bar, England
#
#                  Operator Flight #          Route  \
# 0    Military - U.S. Army      NaN  Demonstration
# 1    Military - U.S. Navy      NaN    Test flight
# 2                 Private        -            NaN
# 3  Military - German Navy      NaN            NaN
# 4  Military - German Navy      NaN            NaN
# ...

# %%
data = data[['Date','Location','Type','Aboard', 'Fatalities','taoshenglv']]#取所需的列,以列表形式获取

# %%
data.describe()#统计描述
# Out:
#             Aboard   Fatalities   taoshenglv
# count  5246.000000  5256.000000  5244.000000
# mean     27.554518    20.068303     0.165068
# std      43.076711    33.199952     0.298771
# min       0.000000     0.000000     0.000000
# 25%       5.000000     3.000000     0.000000
# 50%      13.000000     9.000000     0.000000
# 75%      30.000000    23.000000     0.200000
# max     644.000000   583.000000     1.000000

# %%
data[data.Fatalities>500]#切片查看
# Out:
#             Date                               Location  \
# 2963  03/27/1977               Tenerife, Canary Islands
# 3568  08/12/1985  Mt. Osutaka, near Ueno Village, Japan
#
#                                       Type  Aboard  Fatalities  taoshenglv
# 2963  Boeing B-747-121 / Boeing B-747-206B   644.0       583.0    0.094720
# 3568                     Boeing B-747-SR46   524.0       520.0    0.007634

# %%
data[data.taoshenglv==1]#注意用==双等号来表示等于
# Out:
#             Date                                      Location  \
# 108   10/21/1926                               English Channel
# 387   03/05/1936                            Near Tengya, China
# 889   10/08/1947                           Near El Paso, Texas
# 897   11/11/1947                            Gallup, New Mexico
# 1265  05/25/1953                        Amsterdam, Netherlands
# 1359  01/19/1955                              Des Moines, Iowa
# 1440  09/09/1956                        Bartlesville, Oklahoma
# 1443  10/16/1956                          Over the PacifiOcean
# 1610  06/30/1959         Ishikawa City, Ryukyu Island, Okinawa
# 1837  02/28/1963                         Boston, Massachusetts
# 1868  08/21/1963                       Near Leningrad , Russia
# 1885  12/17/1963                       Los Angeles, California
# 1927  07/16/1964                            Richmond, Virginia
# 1982  06/28/1965                     San Francisco, California
# ...
